# %% [markdown]
# #### Instructions
# It's the moment to perform clustering on the songs you collected. Remember that the ultimate goal of this little project is to improve the recommendations of artists. Clustering the songs will allow the recommendation system to limit the scope of the recommendations to only songs that belong to the same cluster - songs with similar audio features.
#
# The experiments you did with the Spotify API and the Billboard web scraping will allow you to create a pipeline such that when the user enters a song, you:
#
# 1- Check whether or not the song is in the Billboard Hot 200.
#
# 2- Collect the audio features from the Spotify API.
#
# After that, you want to send the Spotify audio features of the submitted song to the clustering model, which should return a cluster number.
#
# We want to have as many songs as possible to create the clustering model, so we will add the songs you collected to a bigger dataset available on Kaggle containing 160 thousand songs.

# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\aidag\miniconda3\lib\site-packages (2.23.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\aidag\miniconda3\lib\site-packages (from spotipy) (5.0.3)
# Requirement already satisfied: requests>=2.25.0 in c:\users\aidag\miniconda3\lib\site-packages (from spotipy) (2.29.0)
# Requirement already satisfied: six>=1.15.0 in c:\users\aidag\miniconda3\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\aidag\miniconda3\lib\site-packages (from spotipy) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aidag\miniconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aidag\miniconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aidag\miniconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2023.7.22)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="d3e2b5055c184ea8bc380f2e44742819",
                                                           client_secret="1b6ccee7c75d4689ae36a30c8e48ed4f"))

lucretia_my_reflection = sp.search(q='track:Lucretia My Reflection', limit=10, type='track')
lucretia_my_reflection
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3ALucretia+My+Reflection&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4HxBVyHaUa60eCSsJWxwWR'},
#        'href': 'https://api.spotify.com/v1/artists/4HxBVyHaUa60eCSsJWxwWR',
#        'id': '4HxBVyHaUa60eCSsJWxwWR',
#        'name': 'Sisters of Mercy',
#        'type': 'artist',
#        'uri': 'spotify:artist:4HxBVyHaUa60eCSsJWxwWR'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2I5WCmOZo17YkcEwjXbLvc'},
#      'href': 'https://api.spotify.com/v1/albums/2I5WCmOZo17YkcEwjXbLvc',
#      'id': '2I5WCmOZo17YkcEwjXbLvc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737f16b5473cc45f755ec03c82',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027f16b5473cc45f755ec03c82',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517f16b5473cc45f755ec03c82',
#        'width': 64}],
#      'name': 'Floodland',
#      'release_date': '1987',
#      'release_date_precision': 'year',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:2I5WCmOZo17YkcEwjXbLvc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4HxBVyHaUa60eCSsJWxwWR'},
#       'href': 'https://api.spotify.com/v1/artists/4HxBVyHaUa60eCSsJWxwWR',
#       'id': '4HxBVyHaUa60eCSsJWxwWR',
#       'name': 'Sisters of Mercy',
#       'type': 'artist',
#       'uri': 'spotify:artist:4HxBVyHaUa60eCSsJWxwWR'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 295250,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCRL1500215'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/20goDx14UZviYtCPtLbqvs'},
#     'href': 'https://api.spotify.com/v1/tracks/20goDx14UZviYtCPtLbqvs',
#     'id': '20goDx14UZviYtCPtLbqvs',
#     'is_local': False,
#     'name': 'Lucretia My Reflection - Vinyl Version',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bfe7f4d87a0701873a9527c77da183ccb405ca91?cid=d3e2b5055c184ea8bc380f2e44742819',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:20goDx14UZviYtCPtLbqvs'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4HxBVyHaUa60eCSsJWxwWR'},
#        'href': 'https://api.spotify.com/v1/artists/4HxBVyHaUa60eCSsJWxwWR',
#        'id': '4HxBVyHaUa60eCSsJWxwWR',
#        'name': 'Sisters of Mercy',
#        'type': 'artist',
#        'uri': 'spotify:artist:4HxBVyHaUa60eCSsJWxwWR'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7eLzF93T0FDx4hkuQ4juEj'},
#      'href': 'https://api.spotify.com/v1/albums/7eLzF93T0FDx4hkuQ4juEj',
#      'id': '7eLzF93T0FDx4hkuQ4juEj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735dce0574efb7374e210ddf48',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025dce0574efb7374e210ddf48',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515dce0574efb7374e210ddf48',
#        'width': 64}],
#      'name': 'Floodland (2006 Remaster; Expanded Deluxe Version)',
#      'release_date': '1987',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:7eLzF93T0FDx4hkuQ4juEj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4HxBVyHaUa60eCSsJWxwWR'},
#       'href': 'https://api.spotify.com/v1/artists/4HxBVyHaUa60eCSsJWxwWR',
#       'id': '4HxBVyHaUa60eCSsJWxwWR',
#       'name': 'Sisters of Mercy',
#       'type': 'artist',
#       'uri': 'spotify:artist:4HxBVyHaUa60eCSsJWxwWR'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 297159,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS0600500'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1FyfPd5AMMjrorTdu3wASG'},
#     'href': 'https://api.spotify.com/v1/tracks/1FyfPd5AMMjrorTdu3wASG',
#     'id': '1FyfPd5AMMjrorTdu3wASG',
#     'is_local': False,
#     'name': 'Lucretia My Reflection',
#     'popularity': 41,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d28f4bea8c9bcbe8f96a85c104131f9379a43d81?cid=d3e2b5055c184ea8bc380f2e44742819',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1FyfPd5AMMjrorTdu3wASG'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24WRvSDW3TaWsPvJ9JwDTx'},
#        'href': 'https://api.spotify.com/v1/artists/24WRvSDW3TaWsPvJ9JwDTx',
#        'id': '24WRvSDW3TaWsPvJ9JwDTx',
#        'name': 'Love Like Blood',
#        'type': 'artist',
#        'uri': 'spotify:artist:24WRvSDW3TaWsPvJ9JwDTx'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3UeHt5tOA29dBYBJ5IjE4q'},
#      'href': 'https://api.spotify.com/v1/albums/3UeHt5tOA29dBYBJ5IjE4q',
#      'id': '3UeHt5tOA29dBYBJ5IjE4q',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730a6d3c1568858e29a6dd9359',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020a6d3c1568858e29a6dd9359',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510a6d3c1568858e29a6dd9359',
#        'width': 64}],
#      'name': 'Chronology of a Love-Affair',
#      'release_date': '2001-03-05',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:3UeHt5tOA29dBYBJ5IjE4q'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24WRvSDW3TaWsPvJ9JwDTx'},
#       'href': 'https://api.spotify.com/v1/artists/24WRvSDW3TaWsPvJ9JwDTx',
#       'id': '24WRvSDW3TaWsPvJ9JwDTx',
#       'name': 'Love Like Blood',
#       'type': 'artist',
#       'uri': 'spotify:artist:24WRvSDW3TaWsPvJ9JwDTx'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 314426,
#     'explicit': False,
#     'external_ids': {'isrc': 'DED830900637'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2XrIWcOPQMwXAxCYQam6jN'},
#     'href': 'https://api.spotify.com/v1/tracks/2XrIWcOPQMwXAxCYQam6jN',
#     'id': '2XrIWcOPQMwXAxCYQam6jN',
#     'is_local': False,
#     'name': 'Lucretia My Reflection',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ffddb4813878bc68b721b1ea6e57bc2cb04e12b8?cid=d3e2b5055c184ea8bc380f2e44742819',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2XrIWcOPQMwXAxCYQam6jN'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4HxBVyHaUa60eCSsJWxwWR'},
#        'href': 'https://api.spotify.com/v1/artists/4HxBVyHaUa60eCSsJWxwWR',
#        'id': '4HxBVyHaUa60eCSsJWxwWR',
#        'name': 'Sisters of Mercy',
#        'type': 'artist',
#        'uri': 'spotify:artist:4HxBVyHaUa60eCSsJWxwWR'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5qjUHQuDQfh8UwkQ9C5udu'},
#      'href': 'https://api.spotify.com/v1/albums/5qjUHQuDQfh8UwkQ9C5udu',
#      'id': '5qjUHQuDQfh8UwkQ9C5udu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273227e14b63f340d3f61c8f012',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02227e14b63f340d3f61c8f012',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851227e14b63f340d3f61c8f012',
#        'width': 64}],
#      'name': 'Greatest Hits Volume One: A Slight Case Of Overbombing (2018 Remaster)',
#      'release_date': '1993-08-23',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5qjUHQuDQfh8UwkQ9C5udu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4HxBVyHaUa60eCSsJWxwWR'},
#       'href': 'https://api.spotify.com/v1/artists/4HxBVyHaUa60eCSsJWxwWR',
#       'id': '4HxBVyHaUa60eCSsJWxwWR',
#       'name': 'Sisters of Mercy',
#       'type': 'artist',
#       'uri': 'spotify:artist:4HxBVyHaUa60eCSsJWxwWR'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 523989,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCRL1800009'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/52PMeKpMnfn7w0aETAMD3a'},
#     'href': 'https://api.spotify.com/v1/tracks/52PMeKpMnfn7w0aETAMD3a',
#     'id': '52PMeKpMnfn7w0aETAMD3a',
#     'is_local': False,
#     'name': 'Lucretia My Reflection - 2018 Remaster',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6e7efdffdf191ca4939547fe7a6ff403ff30074a?cid=d3e2b5055c184ea8bc380f2e44742819',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:52PMeKpMnfn7w0aETAMD3a'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/481O9YRYc0ifnh00ZS6no6'},
#        'href': 'https://api.spotify.com/v1/artists/481O9YRYc0ifnh00ZS6no6',
#        'id': '481O9YRYc0ifnh00ZS6no6',
#        'name': 'Black Light Burns',
#        'type': 'artist',
#        'uri': 'spotify:artist:481O9YRYc0ifnh00ZS6no6'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5YMBQFDWEqi6yDatCDdhji'},
#      'href': 'https://api.spotify.com/v1/albums/5YMBQFDWEqi6yDatCDdhji',
#      'id': '5YMBQFDWEqi6yDatCDdhji',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27376065edfda012f4072b217f7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0276065edfda012f4072b217f7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485176065edfda012f4072b217f7',
#        'width': 64}],
#      'name': 'Cover Your Heart',
#      'release_date': '2008-08-05',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:5YMBQFDWEqi6yDatCDdhji'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/481O9YRYc0ifnh00ZS6no6'},
#       'href': 'https://api.spotify.com/v1/artists/481O9YRYc0ifnh00ZS6no6',
#       'id': '481O9YRYc0ifnh00ZS6no6',
#       'name': 'Black Light Burns',
#       'type': 'artist',
#       'uri': 'spotify:artist:481O9YRYc0ifnh00ZS6no6'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 267786,
#     'explicit': True,
#     'external_ids': {'isrc': 'TCABG1224244'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6LaGLwZapKGZLGWvfu2k3Y'},
#     'href': 'https://api.spotify.com/v1/tracks/6LaGLwZapKGZLGWvfu2k3Y',
#     'id': '6LaGLwZapKGZLGWvfu2k3Y',
#     'is_local': False,
#     'name': 'Lucretia My Reflection',
#     'popularity': 26,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ec330cc068e2865251e0414027434a6b45bfd8e1?cid=d3e2b5055c184ea8bc380f2e44742819',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:6LaGLwZapKGZLGWvfu2k3Y'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qrGnVZhEO4vX3ahn4RY1r'},
#        'href': 'https://api.spotify.com/v1/artists/1qrGnVZhEO4vX3ahn4RY1r',
#        'id': '1qrGnVZhEO4vX3ahn4RY1r',
#        'name': 'Warrel Dane',
#        'type': 'artist',
#        'uri': 'spotify:artist:1qrGnVZhEO4vX3ahn4RY1r'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1GInCtYNFPydxDCuW00VNp'},
#      'href': 'https://api.spotify.com/v1/albums/1GInCtYNFPydxDCuW00VNp',
#      'id': '1GInCtYNFPydxDCuW00VNp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27321b6bcf4958d1f9a643379fd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0221b6bcf4958d1f9a643379fd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485121b6bcf4958d1f9a643379fd',
#        'width': 64}],
#      'name': 'Praises To The War Machine',
#      'release_date': '2008-06-10',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:1GInCtYNFPydxDCuW00VNp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qrGnVZhEO4vX3ahn4RY1r'},
#       'href': 'https://api.spotify.com/v1/artists/1qrGnVZhEO4vX3ahn4RY1r',
#       'id': '1qrGnVZhEO4vX3ahn4RY1r',
#       'name': 'Warrel Dane',
#       'type': 'artist',
#       'uri': 'spotify:artist:1qrGnVZhEO4vX3ahn4RY1r'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 278360,
#     'explicit': False,
#     'external_ids': {'isrc': 'US4E40847804'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2yUkX5Ea2NwodDJPvvsTxR'},
#     'href': 'https://api.spotify.com/v1/tracks/2yUkX5Ea2NwodDJPvvsTxR',
#     'id': '2yUkX5Ea2NwodDJPvvsTxR',
#     'is_local': False,
#     'name': 'Lucretia My Reflection',
#     'popularity': 29,
#     'preview_url': 'https://p.scdn.co/mp3-preview/98728003fc1f250db4dbf0040ffbf75560486b16?cid=d3e2b5055c184ea8bc380f2e44742819',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2yUkX5Ea2NwodDJPvvsTxR'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4HxBVyHaUa60eCSsJWxwWR'},
#        'href': 'https://api.spotify.com/v1/artists/4HxBVyHaUa60eCSsJWxwWR',
#        'id': '4HxBVyHaUa60eCSsJWxwWR',
#        'name': 'Sisters of Mercy',
#        'type': 'artist',
#        'uri': 'spotify:artist:4HxBVyHaUa60eCSsJWxwWR'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/45hGlbZBJac3W0GuKfk9c8'},
#      'href': 'https://api.spotify.com/v1/albums/45hGlbZBJac3W0GuKfk9c8',
#      'id': '45hGlbZBJac3W0GuKfk9c8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27325a0bf458b6b880eafef419f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0225a0bf458b6b880eafef419f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485125a0bf458b6b880eafef419f',
#        'width': 64}],
#      'name': 'Floodland Collection',
#      'release_date': '1987-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:45hGlbZBJac3W0GuKfk9c8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4HxBVyHaUa60eCSsJWxwWR'},
#       'href': 'https://api.spotify.com/v1/artists/4HxBVyHaUa60eCSsJWxwWR',
#       'id': '4HxBVyHaUa60eCSsJWxwWR',
#       'name': 'Sisters of Mercy',
#       'type': 'artist',
#       'uri': 'spotify:artist:4HxBVyHaUa60eCSsJWxwWR'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 295250,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCRL1500215'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7hUJwSsOySplSXvagzQwQZ'},
#     'href': 'https://api.spotify.com/v1/tracks/7hUJwSsOySplSXvagzQwQZ',
#     'id': '7hUJwSsOySplSXvagzQwQZ',
#     'is_local': False,
#     'name': 'Lucretia My Reflection - Vinyl Version',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bfe7f4d87a0701873a9527c77da183ccb405ca91?cid=d3e2b5055c184ea8bc380f2e44742819',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:7hUJwSsOySplSXvagzQwQZ'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/704pDqaroLiTRwJQxVdPO0'},
#        'href': 'https://api.spotify.com/v1/artists/704pDqaroLiTRwJQxVdPO0',
#        'id': '704pDqaroLiTRwJQxVdPO0',
#        'name': 'Dark Chisme',
#        'type': 'artist',
#        'uri': 'spotify:artist:704pDqaroLiTRwJQxVdPO0'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3Ewh73SzIXjhLDe4DFPmKT'},
#      'href': 'https://api.spotify.com/v1/albums/3Ewh73SzIXjhLDe4DFPmKT',
#      'id': '3Ewh73SzIXjhLDe4DFPmKT',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273723517cea03cb6521e15cfae',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02723517cea03cb6521e15cfae',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851723517cea03cb6521e15cfae',
#        'width': 64}],
#      'name': 'Lucretia My Reflection',
#      'release_date': '2023-11-11',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3Ewh73SzIXjhLDe4DFPmKT'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/704pDqaroLiTRwJQxVdPO0'},
#       'href': 'https://api.spotify.com/v1/artists/704pDqaroLiTRwJQxVdPO0',
#       'id': '704pDqaroLiTRwJQxVdPO0',
#       'name': 'Dark Chisme',
#       'type': 'artist',
#       'uri': 'spotify:artist:704pDqaroLiTRwJQxVdPO0'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 277385,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZWFE2339547'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1AhJWvjtWiVBZkQZWmqIML'},
#     'href': 'https://api.spotify.com/v1/tracks/1AhJWvjtWiVBZkQZWmqIML',
#     'id': '1AhJWvjtWiVBZkQZWmqIML',
#     'is_local': False,
#     'name': 'Lucretia My Reflection',
#     'popularity': 15,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e04c9ba576a9f35338af7a850afa3f3744abecd3?cid=d3e2b5055c184ea8bc380f2e44742819',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1AhJWvjtWiVBZkQZWmqIML'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4HxBVyHaUa60eCSsJWxwWR'},
#        'href': 'https://api.spotify.com/v1/artists/4HxBVyHaUa60eCSsJWxwWR',
#        'id': '4HxBVyHaUa60eCSsJWxwWR',
#        'name': 'Sisters of Mercy',
#        'type': 'artist',
#        'uri': 'spotify:artist:4HxBVyHaUa60eCSsJWxwWR'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/45hGlbZBJac3W0GuKfk9c8'},
#      'href': 'https://api.spotify.com/v1/albums/45hGlbZBJac3W0GuKfk9c8',
#      'id': '45hGlbZBJac3W0GuKfk9c8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27325a0bf458b6b880eafef419f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0225a0bf458b6b880eafef419f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485125a0bf458b6b880eafef419f',
#        'width': 64}],
#      'name': 'Floodland Collection',
#      'release_date': '1987-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:45hGlbZBJac3W0GuKfk9c8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4HxBVyHaUa60eCSsJWxwWR'},
#       'href': 'https://api.spotify.com/v1/artists/4HxBVyHaUa60eCSsJWxwWR',
#       'id': '4HxBVyHaUa60eCSsJWxwWR',
#       'name': 'Sisters of Mercy',
#       'type': 'artist',
#       'uri': 'spotify:artist:4HxBVyHaUa60eCSsJWxwWR'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 4,
#     'duration_ms': 591288,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1500410'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3kJDfttDmnaMEU4gKyZRJU'},
#     'href': 'https://api.spotify.com/v1/tracks/3kJDfttDmnaMEU4gKyZRJU',
#     'id': '3kJDfttDmnaMEU4gKyZRJU',
#     'is_local': False,
#     'name': 'Lucretia My Reflection - 12" Version',
#     'popularity': 24,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1dc2356c85c8a1f8ef7ce1acd458b283ce638e45?cid=d3e2b5055c184ea8bc380f2e44742819',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3kJDfttDmnaMEU4gKyZRJU'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/07CIogD8ks33mLMSRLpBPL'},
#        'href': 'https://api.spotify.com/v1/artists/07CIogD8ks33mLMSRLpBPL',
#        'id': '07CIogD8ks33mLMSRLpBPL',
#        'name': 'DSTR',
#        'type': 'artist',
#        'uri': 'spotify:artist:07CIogD8ks33mLMSRLpBPL'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2rX305moT4ZbnkKAMvl1VP'},
#      'href': 'https://api.spotify.com/v1/albums/2rX305moT4ZbnkKAMvl1VP',
#      'id': '2rX305moT4ZbnkKAMvl1VP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273480639050695138a43f23c93',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02480639050695138a43f23c93',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851480639050695138a43f23c93',
#        'width': 64}],
#      'name': 'Silent World EP',
#      'release_date': '2010-04-02',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:2rX305moT4ZbnkKAMvl1VP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/07CIogD8ks33mLMSRLpBPL'},
#       'href': 'https://api.spotify.com/v1/artists/07CIogD8ks33mLMSRLpBPL',
#       'id': '07CIogD8ks33mLMSRLpBPL',
#       'name': 'DSTR',
#       'type': 'artist',
#       'uri': 'spotify:artist:07CIogD8ks33mLMSRLpBPL'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 333013,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEZ651000425'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7meEHt7fPaPqFaHOgk0zcS'},
#     'href': 'https://api.spotify.com/v1/tracks/7meEHt7fPaPqFaHOgk0zcS',
#     'id': '7meEHt7fPaPqFaHOgk0zcS',
#     'is_local': False,
#     'name': 'Lucretia My Reflection',
#     'popularity': 16,
#     'preview_url': 'https://p.scdn.co/mp3-preview/84be96f9511e32911e2e6e8cf7e00320f64a8052?cid=d3e2b5055c184ea8bc380f2e44742819',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:7meEHt7fPaPqFaHOgk0zcS'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=track%3ALucretia+My+Reflection&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 76}}

# %%
lucretia_my_reflection.keys()
# Out:
# dict_keys(['tracks'])

# %%
lucretia_my_reflection['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
lucretia_my_reflection["tracks"]["items"][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
lucretia_my_reflection["tracks"]["items"][0]['uri']
# Out:
# 'spotify:track:20goDx14UZviYtCPtLbqvs'

# %%
lucretia_my_reflection['tracks']['total']
# Out:
# 76

# %%
track_ids = [track['uri'] for track in lucretia_my_reflection['tracks']['items']]

# %%
start = 0
df = pd.DataFrame()

for stop in range(0, len(track_ids)+100, 100):
    if start != stop:
        print(start, stop)
        new_df = pd.json_normalize(sp.audio_features(track_ids[start:stop]))
        df = pd.concat([new_df, df])
        start = stop

df.reset_index(inplace=True)
# Out:
# 0 100

# %%
df.head(10)
# Out:
#    index  danceability  energy  key  loudness  mode  speechiness  \
# 0      0         0.601   0.768    9    -8.718     1       0.0329
# 1      1         0.602   0.776    9    -9.204     1       0.0311
# 2      2         0.623   0.787    0    -6.629     1       0.0365
# 3      3         0.591   0.791    9    -7.421     0       0.0330
# 4      4         0.488   0.980    7    -2.842     1       0.0884
# 5      5         0.579   0.827    5    -5.662     1       0.0298
# 6      6         0.601   0.768    9    -8.718     1       0.0329
# 7      7         0.532   0.980    7    -7.074     1       0.0363
# 8      8         0.610   0.798    2    -9.248     0       0.0380
# 9      9         0.636   0.661    9    -8.477     1       0.0308
#
#    acousticness  instrumentalness  liveness  valence    tempo            type  \
# 0      0.078500            0.7120    0.0771    0.887  130.342  audio_features
# 1      0.129000            0.7700    0.1930    0.923  129.458  audio_features
# 2      0.000257            0.6860    0.0408    0.768  129.990  audio_features
# 3      0.002380            0.7230    0.0612    0.815  130.142  audio_features
# 4      0.005160            0.7650    0.0875    0.441  147.066  audio_features
# 5      0.000068            0.0345    0.1220    0.353  130.045  audio_features
# 6      0.078500            0.7120    0.0771    0.887  130.342  audio_features
# 7      0.000403            0.0532    0.0763    0.614  137.965  audio_features
# 8      0.005110            0.7750    0.0533    0.783  130.351  audio_features
# 9      0.001790            0.5250    0.0839    0.921  130.191  audio_features
#
#                        id                                   uri  \
# 0  20goDx14UZviYtCPtLbqvs  spotify:track:20goDx14UZviYtCPtLbqvs
# 1  1FyfPd5AMMjrorTdu3wASG  spotify:track:1FyfPd5AMMjrorTdu3wASG
# 2  2XrIWcOPQMwXAxCYQam6jN  spotify:track:2XrIWcOPQMwXAxCYQam6jN
# 3  52PMeKpMnfn7w0aETAMD3a  spotify:track:52PMeKpMnfn7w0aETAMD3a
# 4  6LaGLwZapKGZLGWvfu2k3Y  spotify:track:6LaGLwZapKGZLGWvfu2k3Y
# 5  2yUkX5Ea2NwodDJPvvsTxR  spotify:track:2yUkX5Ea2NwodDJPvvsTxR
# 6  7hUJwSsOySplSXvagzQwQZ  spotify:track:7hUJwSsOySplSXvagzQwQZ
# 7  1AhJWvjtWiVBZkQZWmqIML  spotify:track:1AhJWvjtWiVBZkQZWmqIML
# 8  3kJDfttDmnaMEU4gKyZRJU  spotify:track:3kJDfttDmnaMEU4gKyZRJU
# 9  7meEHt7fPaPqFaHOgk0zcS  spotify:track:7meEHt7fPaPqFaHOgk0zcS
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/20goDx14UZvi...
# 1  https://api.spotify.com/v1/tracks/1FyfPd5AMMjr...
# 2  https://api.spotify.com/v1/tracks/2XrIWcOPQMwX...
# 3  https://api.spotify.com/v1/tracks/52PMeKpMnfn7...
# 4  https://api.spotify.com/v1/tracks/6LaGLwZapKGZ...
# 5  https://api.spotify.com/v1/tracks/2yUkX5Ea2Nwo...
# 6  https://api.spotify.com/v1/tracks/7hUJwSsOySpl...
# 7  https://api.spotify.com/v1/tracks/1AhJWvjtWiVB...
# 8  https://api.spotify.com/v1/tracks/3kJDfttDmnaM...
# 9  https://api.spotify.com/v1/tracks/7meEHt7fPaPq...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/20go...       295250
# 1  https://api.spotify.com/v1/audio-analysis/1Fyf...       297160
# 2  https://api.spotify.com/v1/audio-analysis/2XrI...       314427
# 3  https://api.spotify.com/v1/audio-analysis/52PM...       523989
# 4  https://api.spotify.com/v1/audio-analysis/6LaG...       267787
# 5  https://api.spotify.com/v1/audio-analysis/2yUk...       278360
# 6  https://api.spotify.com/v1/audio-analysis/7hUJ...       295250
# 7  https://api.spotify.com/v1/audio-analysis/1AhJ...       277386
# 8  https://api.spotify.com/v1/audio-analysis/3kJD...       591288
# 9  https://api.spotify.com/v1/audio-analysis/7meE...       333013
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               4
# 7               4
# 8               4
# 9               4

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import joblib
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id = 'd3e2b5055c184ea8bc380f2e44742819'
client_secret = '1b6ccee7c75d4689ae36a30c8e48ed4f'

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

def get_audio_features(track_ids):
    audio_features = []
    for start in range(0, len(track_ids), 100):
        stop = min(start + 100, len(track_ids))
        try:
            new_df = pd.json_normalize(sp.audio_features(track_ids[start:stop]))
            audio_features.append(new_df)
        except ConnectionError:
            print("Error de conexión.")
    return pd.concat(audio_features)

track_ids = ['spotify:track:20goDx14UZviYtCPtLbqvs']  

audio_features_df = get_audio_features(track_ids)

audio_features_df = audio_features_df.select_dtypes(include=['number'])

audio_features_df.dropna(inplace=True)

scaler = StandardScaler()
scaled_features = scaler.fit_transform(audio_features_df)

if len(audio_features_df) < 10:
    raise ValueError("Not enough.")

kmeans = KMeans(n_clusters=10, random_state=42)
kmeans.fit(scaled_features)

audio_features_df['cluster'] = kmeans.labels_

joblib.dump(kmeans, 'kmeans_model.pkl')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 30
#      27 scaled_features = scaler.fit_transform(audio_features_df)
#      29 if len(audio_features_df) < 10:
# ---> 30     raise ValueError("Not enough.")
#      32 kmeans = KMeans(n_clusters=10, random_state=42)
#      33 kmeans.fit(scaled_features)
#
# ValueError: Not enough.
